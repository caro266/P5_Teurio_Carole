# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
import nltk
import re
import string
import seaborn as sns
from wordcloud import WordCloud
import spacy
from bs4 import BeautifulSoup
from tqdm import tqdm
tqdm.pandas()

# %%
pd.set_option('max_columns', None)
pd.set_option("max_rows", None)
pd.set_option("max_colwidth", 1000)

# %%
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /home/kro/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/kro/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
dataStack = pd.read_csv("../QueryResults.csv")
dataStack["CreationDate"] = pd.to_datetime(dataStack["CreationDate"])
dataStack["CreationYear"] = dataStack["CreationDate"].dt.year
dataStack.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17808 entries, 0 to 17807
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Id                     17808 non-null  int64
#  1   PostTypeId             17808 non-null  int64
#  2   AcceptedAnswerId       15813 non-null  float64
#  3   ParentId               0 non-null      float64
#  4   CreationDate           17808 non-null  datetime64[ns]
#  5   DeletionDate           0 non-null      float64
#  6   Score                  17808 non-null  int64
#  7   ViewCount              17808 non-null  int64
#  8   Body                   17808 non-null  object
#  9   OwnerUserId            17369 non-null  float64
#  10  OwnerDisplayName       2863 non-null   object
#  11  LastEditorUserId       16452 non-null  float64
#  12  LastEditorDisplayName  1944 non-null   object
#  13  LastEditDate           16672 non-null  object
#  14  LastActivityDate       17808 non-null  object
#  15  Title                  17808 non-null  object
#  16  Tags                   17808 non-null  object
#  17  AnswerCount            17808 non-null  int64
#  18  CommentCount           17808 non-null  int64
#  19  FavoriteCount          17808 non-null  int64
#  20  ClosedDate             1581 non-null   object
#  21  CommunityOwnedDate     442 non-null    object
#  22  ContentLicense         17808 non-null  object
#  23  CreationYear           17808 non-null  int64
# dtypes: datetime64[ns](1), float64(5), int64(8), object(10)
# memory usage: 3.3+ MB

# %%
dataStack.head()
# Out:
#          Id  PostTypeId  AcceptedAnswerId  ParentId        CreationDate  \
# 0      7284           1            7320.0       NaN 2008-08-10 18:41:02
# 1      7492           1               NaN       NaN 2008-08-11 03:00:26
# 2      7551           1            7618.0       NaN 2008-08-11 05:44:42
# 3  19551298           1               NaN       NaN 2013-10-23 20:06:51
# 4   3301956           1         3302018.0       NaN 2010-07-21 17:15:13
#
#    DeletionDate  Score  ViewCount  \
# 0           NaN    566     210026
# 1           NaN    246     161018
# 2           NaN    834     311974
# 3           NaN    226     231871
# 4           NaN    206      63726
#
#                                                 Body  OwnerUserId  ...  \
# 0  <p>What does the expression "Turing Complete" ...        198.0  ...
# 1  <p>In the past, I used Microsoft Web Applicati...        556.0  ...
# 2  <p>When designing a REST API or service are th...        541.0  ...
# 3  <p>I installed Mac OS X Mavericks (10.9) yeste...    1457520.0  ...
# 4  <p>I have a bare repository that's used as the...     232452.0  ...
#
#       LastActivityDate                                              Title  \
# 0  2021-04-10 17:47:05                           What is Turing Complete?
# 1  2018-08-30 15:01:26       Performing a Stress Test on Web Application?
# 2  2017-12-28 16:38:45  Best Practices for securing a REST API / web s...
# 3  2021-04-20 15:34:50  App can't be opened because it is from an unid...
# 4  2020-08-15 20:56:40  Git: Correct way to change Active Branch in a ...
#
#                                                 Tags AnswerCount CommentCount  \
# 0         <theory><turing-machines><turing-complete>          15            2
# 1  <web-applications><stress-testing><performance...          30            0
# 2  <wcf><security><rest><authorization><rest-secu...          18            1
# 3                           <eclipse><osx-mavericks>          16            6
# 4                                              <git>           6            5
#
#   FavoriteCount           ClosedDate  CommunityOwnedDate  ContentLicense  \
# 0           184                  NaN                 NaN    CC BY-SA 3.0
# 1           174                  NaN                 NaN    CC BY-SA 3.0
# 2           683  2018-03-29 17:53:13                 NaN    CC BY-SA 2.5
# 3            37                  NaN                 NaN    CC BY-SA 3.0
# 4            66                  NaN                 NaN    CC BY-SA 3.0
#
#    CreationYear
# 0          2008
# 1          2008
# 2          2008
# 3          2013
# 4          2010
#
# [5 rows x 24 columns]

# %%
dataTemp = dataStack.groupby(by="CreationYear").count()
dataTemp = dataTemp.iloc[:,0]
fig = plt.figure(figsize=(20, 8))
dataTemp.plot(figsize=(12,8),
          title="Evolution des questions",
          ylabel="Nombre de questions",
          xlabel="Année",
          legend=False)
# Out:
# <AxesSubplot:title={'center':'Evolution des questions'}, xlabel='Année', ylabel='Nombre de questions'>

# %% [markdown]
# # Fonctions

# %%
def getListTag(listToWork,sep,years="All"):
    """ 
    Fonction qui compte le nombre de mots différents
    listToWork : Dataframe
    sep : Séparateur pour spliter
    years : l'année pour laquelle on travaille
    """
    tagList=[]
    tempData = dataStack.copy()
    
    if years != "All":
        tempData = tempData[tempData['CreationYear']==years]
    for tags in tempData[listToWork]:
        for mot in tags.split(sep):
            tagList.append(mot)
            
    dfTagList = pd.DataFrame(tagList, columns=["Tag"])
    dfTagList = dfTagList.groupby("Tag")\
        .agg(tagCount=pd.NamedAgg(column="Tag", aggfunc="count"))
    dfTagList.sort_values("tagCount", ascending=False, inplace=True)

    return dfTagList

# %%
def keep_info(listInfo,toKeep):
    """Return the list of information which is in the 'keep list'"""
    loc = []
    try:
        if listInfo != 'nan':
            for word in listInfo.split(','):
                if word in toKeep.index:
                    loc.append(word)
    except:
        print("Except ",listInfo)
    return ','.join(loc)

# %%
def nettoyageGe(listToClean):
    
    # Lower case
    locList = listToClean.lower()

    # Remove ponctuation sauf #
    locList = re.sub('[^\\w\\s#]', '', locList)
    # Remove digit
    locList = re.sub(r'\w*\d+\w*', '', locList)
    # Remove links
    locList = re.sub(r'http*\S+', '', locList)
    # Remove \n
    locList = locList.replace("\n"," ")
    # Change some words
    locList = locList.replace("i'm","i am")
    locList = locList.replace("i've","i have")
    locList = locList.replace("i'd","i would")
    locList = locList.replace("don't","do not")
    locList = locList.replace("that's","that is")
    # On supprime les espaces en trop
    locList=" ".join(locList.split())
    locList = locList.replace("c #","c#")
    
    return(locList)

# %%
def getWord(listToWork):
    """ 
    Fonction qui compte le nombre de mots différents
    listToWork : Dataframe
    """
    motList=[]
    tempData = dataStack[listToWork].copy()
    
    for listData in tempData:
        for mot in listData:
            motList.append(mot)
            
    dfMotList = pd.DataFrame(motList, columns=["Mot"])
    dfMotList = dfMotList.groupby("Mot")\
        .agg(Count=pd.NamedAgg(column="Mot", aggfunc="count"))
    dfMotList.sort_values("Count", ascending=False, inplace=True)
    
    return dfMotList

# %% [markdown]
# # Tags

# %%
dataStack['MainTags']=dataStack['Tags'].str.replace("<","")
dataStack['MainTags']=dataStack['MainTags'].str.replace(">",",")
dataStack['MainTags']=dataStack['MainTags'].str[:-1]

# %%
listTags = getListTag('MainTags',',')
#listTags

# %%
#On garde les 40 plus utilisés
listTags=listTags.iloc[:40]
#listTags

# %%
fig = plt.figure(figsize=(15, 10))

listTags.plot(figsize=(12,8), kind="bar",
          title="Number of tags' occurence",
          ylabel="Nb occurence",
          xlabel="Tags",
          legend=False)
plt.xticks(np.arange(len(listTags)),listTags.index)
plt.show()

# %%
# Word cloud 
fig = plt.figure(1, figsize=(10, 8))
ax = fig.add_subplot(1, 1, 1)
wordcloud = WordCloud(width=900, height=500,
                      background_color="black",
                      max_words=500, relative_scaling=1,
                      normalize_plurals=False)\
    .generate_from_frequencies(listTags.to_dict()['tagCount'])

ax.imshow(wordcloud, interpolation='bilinear')
ax.axis("off")
plt.title("Word Cloud des 40 meilleurs tags sur StackOverflow\n",
          fontsize=18, color="#641E16")
plt.show()

# %%
# keep top 40 tags
dataStack['MainTags']=dataStack['MainTags'].apply(lambda x : keep_info(x,listTags))

# %%
# On garde ceux qui ont des tags
dataStack=dataStack[dataStack['MainTags']!=""]

# %%
dataStack['MainTags']= dataStack['MainTags'].str.replace(',',' ')

# %%
dataStack['MainTags'].head()
# Out:
# 1             performance
# 4                     git
# 5                     git
# 6    python string arrays
# 7                 c# list
# Name: MainTags, dtype: object

# %%
# Tokenization
dataStack['MainTags'] = dataStack['MainTags'].apply(nltk.tokenize.word_tokenize)

# %% [markdown]
# # Title

# %%
fig = plt.figure(figsize=(20, 12))
ax = sns.countplot(x=dataStack.Title.str.len())
start, end = ax.get_xlim()
ax.xaxis.set_ticks(np.arange(0, end, 5))
plt.axvline(dataStack.Title.str.len().median() - dataStack.Title.str.len().min(),
            color="r", linestyle='--',
            label="Taille median des titres : "+str(dataStack.Title.str.len().median()))
ax.set_xlabel("Longueur")
plt.title("Longueur des titres",
          fontsize=18, color="#641E16")
plt.legend()
plt.show()

# %%
dataStack['MainWordTitle'] = dataStack['Title'].progress_apply(lambda x : nettoyageGe(x))
# Out:
# 100%|██████████| 14657/14657 [00:00<00:00, 118428.79it/s]

# %%
dataStack['Title'].head()
# Out:
# 1         Performing a Stress Test on Web Application?
# 4    Git: Correct way to change Active Branch in a ...
# 5               Are multiple `.gitignore`s frowned on?
# 6                           Python csv string to array
# 7    How to Sort a List<T> by a property in the object
# Name: Title, dtype: object

# %%
dataStack['MainWordTitle'].head(20)
# Out:
# 1           performing a stress test on web application
# 4     git correct way to change active branch in a b...
# 5                    are multiple gitignores frowned on
# 6                            python csv string to array
# 7       how to sort a listt by a property in the object
# 8     how to convert existing nonempty directory int...
# 9                        remove duplicate rows in mysql
# 10    to prevent a memory leak the jdbc driver has b...
# 11    what is the maximum recursion depth in python ...
# 12         database table and column naming conventions
# 13      how to resolve symbolic links in a shell script
# 14    getting type or namespace name could not be fo...
# 16                                  #pragma pack effect
# 17                        sending  post request in java
# 18    are there any reasons to use private propertie...
# 19                can i make a button not submit a form
# 20     console is undefined error for internet explorer
# 21     how to determine the current shell im working on
# 22        given a class see if instance has method ruby
# 23          uitableviewcell show delete button on swipe
# Name: MainWordTitle, dtype: object

# %%
nlp = spacy.load('en_core_web_sm')
pos_list = ["NOUN","PROPN"]

# %%
# On garde nom et prono
def keepNomEtPronom(info):
    doc = nlp(info)
    list_text_row = []
    for token in doc:
        if(token.pos_ in pos_list):
            list_text_row.append(token.text)
    list_text = " ".join(list_text_row)
    list_text = list_text.replace("c #", "c#")
    list_text_row = []
    return list_text

# %%
dataStack['MainWordTitle'] = dataStack['MainWordTitle'].progress_apply(lambda x : keepNomEtPronom(x))
# Out:
# 100%|██████████| 14657/14657 [00:42<00:00, 340.95it/s]

# %%
dataStack['MainWordTitle'].head(20)
# Out:
# 1                  stress test web application
# 4                    git way branch repository
# 5                                   gitignores
# 6                            python csv string
# 7                        listt property object
# 8     directory git directory files repository
# 9                                   rows mysql
# 10                     memory leak jdbc driver
# 11                      recursion depth python
# 12    database table column naming conventions
# 13                          links shell script
# 14                         type namespace name
# 16                                 pack effect
# 17                                post request
# 18                       reasons properties c#
# 19                                 button form
# 20             console error internet explorer
# 21                                       shell
# 22              class see instance method ruby
# 23                uitableviewcell button swipe
# Name: MainWordTitle, dtype: object

# %%
# Tokenization
dataStack['MainWordTitle'] = dataStack['MainWordTitle'].apply(nltk.tokenize.word_tokenize)

# %%
dataStack['MainWordTitle'].head(20)
# Out:
# 1                   [stress, test, web, application]
# 4                     [git, way, branch, repository]
# 5                                       [gitignores]
# 6                              [python, csv, string]
# 7                          [listt, property, object]
# 8     [directory, git, directory, files, repository]
# 9                                      [rows, mysql]
# 10                      [memory, leak, jdbc, driver]
# 11                        [recursion, depth, python]
# 12    [database, table, column, naming, conventions]
# 13                            [links, shell, script]
# 14                           [type, namespace, name]
# 16                                    [pack, effect]
# 17                                   [post, request]
# 18                       [reasons, properties, c, #]
# 19                                    [button, form]
# 20              [console, error, internet, explorer]
# 21                                           [shell]
# 22              [class, see, instance, method, ruby]
# 23                  [uitableviewcell, button, swipe]
# Name: MainWordTitle, dtype: object

# %%
# Lemmatizer
wn = nltk.WordNetLemmatizer()
dataStack['MainWordTitle'] = dataStack['MainWordTitle'].apply(lambda x : [wn.lemmatize(word) for word in x])

# %%
dataStack['MainWordTitle'].head(20)
# Out:
# 1                  [stress, test, web, application]
# 4                    [git, way, branch, repository]
# 5                                      [gitignores]
# 6                             [python, csv, string]
# 7                         [listt, property, object]
# 8     [directory, git, directory, file, repository]
# 9                                      [row, mysql]
# 10                     [memory, leak, jdbc, driver]
# 11                       [recursion, depth, python]
# 12    [database, table, column, naming, convention]
# 13                            [link, shell, script]
# 14                          [type, namespace, name]
# 16                                   [pack, effect]
# 17                                  [post, request]
# 18                         [reason, property, c, #]
# 19                                   [button, form]
# 20             [console, error, internet, explorer]
# 21                                          [shell]
# 22             [class, see, instance, method, ruby]
# 23                 [uitableviewcell, button, swipe]
# Name: MainWordTitle, dtype: object

# %%
# StopWords
sw = set()
sw.update(tuple(nltk.corpus.stopwords.words('english')))

dataStack['MainWordTitle'] = dataStack['MainWordTitle'].apply(lambda x : [mot for mot in x
                       if mot not in sw])

# %%
listTitle = getWord('MainWordTitle')

# %%
# Word cloud 
fig = plt.figure(1, figsize=(10, 8))
ax = fig.add_subplot(1, 1, 1)
wordcloud = WordCloud(width=900, height=500,
                      background_color="black",
                      max_words=500, relative_scaling=1,
                      normalize_plurals=False)\
    .generate_from_frequencies(listTitle.to_dict()['Count'])

ax.imshow(wordcloud, interpolation='bilinear')
ax.axis("off")
plt.title("Word Cloud des 40 meilleurs tags sur StackOverflow\n",
          fontsize=18, color="#641E16")
plt.show()

# %% [markdown]
# # Body

# %%
fig = plt.figure(figsize=(20, 12))
ax = sns.countplot(x=dataStack.Body.str.len())
start, end = ax.get_xlim()
ax.xaxis.set_ticks(np.arange(0, end, 5))
plt.axvline(dataStack.Body.str.len().median() - dataStack.Body.str.len().min(),
            color="r", linestyle='--',
            label="Taille median des body : "+str(dataStack.Body.str.len().median()))
ax.set_xlabel("Longueur")
plt.title("Longueur des titres",
          fontsize=18, color="#641E16")
plt.legend()
plt.show()

# %%
# Supprimer les tag <code>
def SuppCode(x):
    soup = BeautifulSoup(x,"html.parser")
    code_to_remove = soup.findAll("code")
    for code in code_to_remove:
        code.replace_with(" ")
    return str(soup)

# %%
# Regrouper c et #
def RegCSharp(x):
    test = x.copy()
    while '#' in test : 
        print(test)
        idx = test.index('#')
        if(test[idx-1]=='c'):
            test[idx]="c#"
            del(test[idx-1])
        else:
            del(test[idx])
        
        print(test)
        print('-'*20)

# %%
#dataStack['Body'].head()

# %%
# Delete htlm et code tags
dataStack['MainWordBody'] = dataStack['Body'].apply(SuppCode)
# Delete all html tags
dataStack['MainWordBody'] = [BeautifulSoup(text,"html.parser").get_text() for text in dataStack['MainWordBody']]

#Nettoyage général
dataStack['MainWordBody'] = dataStack['MainWordBody'].progress_apply(lambda x : nettoyageGe(x))
# Out:
# 100%|██████████| 14657/14657 [00:00<00:00, 21047.28it/s]

# %%
#dataStack['MainWordBody'].head()

# %%
dataStack['MainWordBody'] = dataStack['MainWordBody'].progress_apply(lambda x : keepNomEtPronom(x))
print(dataStack['MainWordBody'].head())
# Tokenization
dataStack['MainWordBody'] = dataStack['MainWordBody'].apply(nltk.tokenize.word_tokenize)
print(dataStack['MainWordBody'].head())
# Out:
# 100%|██████████| 14657/14657 [01:44<00:00, 140.70it/s]
# 1    past microsoft web application stress tool pylot stress test web applications d home page login script site walkthrough ecommerce site items cart checkout homepage handful developers problem scalability problems stage launch url tools microsoft homer microsoft web application stress tool pylot reports tools sense hours kind load site bugs bottlenecks instance web server misconfigurations tools success approach part kind formula number users app numbers stress test application
# 4                                                                                                                                                                                                                                                   repository store project developers clone checkout master branch branch question branch file directory work tree refsheadsmaster refsheadsotherbranch repository production one file commit git version way default branch bit way directory file
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                        repo projects file root repo ones practice analysis approach
# 6                                                                                                                                                                                                                                                                                                                                                                                                                             library function csv string array csv module examples filepaths strings
# 7                                                                                                                                                                                                                                                                                                                                                                                                                      class properties list class list property object example order date order i c#
# Name: MainWordBody, dtype: object
# 1    [past, microsoft, web, application, stress, tool, pylot, stress, test, web, applications, d, home, page, login, script, site, walkthrough, ecommerce, site, items, cart, checkout, homepage, handful, developers, problem, scalability, problems, stage, launch, url, tools, microsoft, homer, microsoft, web, application, stress, tool, pylot, reports, tools, sense, hours, kind, load, site, bugs, bottlenecks, instance, web, server, misconfigurations, tools, success, approach, part, kind, formula, number, users, app, numbers, stress, test, application]
# 4                                                                                                                                                                                                                                                                                       [repository, store, project, developers, clone, checkout, master, branch, branch, question, branch, file, directory, work, tree, refsheadsmaster, refsheadsotherbranch, repository, production, one, file, commit, git, version, way, default, branch, bit, way, directory, file]
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  [repo, projects, file, root, repo, ones, practice, analysis, approach]
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      [library, function, csv, string, array, csv, module, examples, filepaths, strings]
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                          [class, properties, list, class, list, property, object, example, order, date, order, i, c, #]
# Name: MainWordBody, dtype: object

# %%
dataStack['MainWordBody'].apply(lambda x : RegCSharp(x))
#print(dataStack['MainWordBody'].head())
# Out:
# --------------------
# --------------------
# --------------------
# --------------------
# ['class', 'properties', 'list', 'class', 'list', 'property', 'object', 'example', 'order', 'date', 'order', 'i', 'c', '#']
# ['class', 'properties', 'list', 'class', 'list', 'property', 'object', 'example', 'order', 'date', 'order', 'i', 'c#']
# -----
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# ['c', '#', 'property', 'construct', 'access', 'modifier', 'field', 'ceremony', 'field', 'use', 'case', 'classes', 'getset', 'logic', 'value', 'property', 'properties', 'methods', 'logic', 'eg', 'properties', 'c', '#', 'reason', 'technicallypossibleyetrarelyusedinactualcode', 'answers', 'uses', 'properties', 'fields', 'fields', 'logic', 'values', 'fields', 'debug', 'order', 'contract', 'property', 'part', 'serialization', 'variables', 'class']
# ['c#', 'property', 'construct', 'access', 'modifier', 'field', 'ceremony', 'field', 'use', 'case', 'classes', 'getset', 'logic', 'value', 'property', 'properties', 'methods', 'logic', 'eg', 'properties', 'c', '#', 'reason', 'technicallypossibleyetrarelyusedinactualcode', 'answers', 'uses', 'properties', 'fields', 'fields', 'logic', 'values', 'fields', 'debug', 'order', 'contract', 'property', 'part', 'serialization', 'variables', 'class']
# -----
# ['c#', 'property', 'construct', 'access', 'modifier', 'field', 'ceremony', 'field', 'use', 'case', 'classes', 'getset', 'logic', 'value', 'property', 'properties', 'methods', 'logic', 'eg', 'properties', 'c', '#', 'reason', 'technicallypossibleyetrarelyusedinactualcode', 'answers', 'uses', 'properties', 'fields', 'fields', 'logic', 'values', 'fields', 'debug', 'order', 'contract', 'property', 'part', 'serialization', 'variables', 'class']
# ['c#', 'property', 'construct', 'access', 'modifier', 'field', 'ceremony', 'field', 'use', 'case', 'classes', 'getset', 'logic', 'value', 'property', 'properties', 'methods', 'logic', 'eg', 'properties', 'c#', 'reason', 'technicallypossibleyetrarelyusedinactualcode', 'answers', 'uses', 'properties', 'fields', 'fields', 'logic', 'values', 'fields', 'debug', 'order', 'contract', 'property', 'part', 'serialization', 'variables', 'class']
# -----
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# ['pieces', 'c', '#', 'code', 'i', 'd', 'number', 'variable']
# ['pieces', 'c#', 'code', 'i', 'd', 'number', 'variable']
# -----
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# ['c', '#', 'linq', 'objects', 'clauses', 'way', 'clause', 'problem', 'join', 'solution', 'join', 'solution', 'class']
# ['c#', 'linq', 'objects', 'clauses', 'way', 'clause', 'problem', 'join', 'solution', 'join', 'solution', 'class']
# -----
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# ['use', 'var', 'keyword', 'c', '#', 'type', 'declaration', 'syntax', 'var']
# ['use', 'var', 'keyword', 'c#', 'type', 'declaration', 'syntax', 'var']
# -----
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# ['c', '#', 'tpl', 'task', 'parallel', 'library', 'class', 'work', 'value', 'type', 't', 'i', 'need', 'taskfromresult', 'method', 'scenario', 'value', 'hand', 'need', 'task', 'thing', 'mind', 'adapter', 'methods', 'task', 'instance']
# ['c#', 'tpl', 'task', 'parallel', 'library', 'class', 'work', 'value', 'type', 't', 'i', 'need', 'taskfromresult', 'method', 'scenario', 'value', 'hand', 'need', 'task', 'thing', 'mind', 'adapter', 'methods', 'task', 'instance']
# -----
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# ['singlepage', 'webapp', 'web', 'service', 'calls', 'post', 'json', 'data', 'rest', 'url', 'request', 'json', 'response', 'json', 'request', 'response', 'binary', 'client', 'jquery', 'app', 'data', 'web', 'page', 'dom', 'elements', 'json', 'data', '#', 'webservice', 'point', 'view', 'file', 'json', 'parameters', 'way', '#', 'client', 'javascript', 'code', 'file', 'call', 'browser', 'file', 'server', 'headers', 'idea', 'pdf', 'server', 'json', 'url', 'file', 'call', 'success', 'handler', 'following', 'call', 'server', 'server', 'files', 'storage', 'area', 'way', 'ideas', 'docs', 'response', 'datatype', 'way', 'file', 'request', 'file', 'data', 'uri', 'scheme', 'vinayc', 'answer', 'options', 'form', 'post', 'json', 'data', 'form', 'values', 'iframes', 'json', 'data', 'query', 'string', 'get', 'request', 'windowlocationhref', 'url', 'eventpreventdefault', 'handler', 'browser', 'application', 'url', 'idea', 'suggestions', 'answer', 'request', 'parameter', 'webservice', 'call', 'web', 'service', 'call', 'json', 'url', 'resource', 'resource', 'file', 'option', 'way', 'information', 'request', 'time', 'size', 'file', 'error', 'messages', 'information', 'download', 'downside', 'file', 'management', 'server', 'ways', 'proscons', 'methods']
# ['singlepage', 'webapp', 'web', 'service', 'calls', 'post', 'json', 'data', 'rest', 'url', 'request', 'json', 'response', 'json', 'request', 'response', 'binary', 'client', 'jquery', 'app', 'data', 'web', 'page', 'dom', 'elements', 'json', 'c#', 'webservice', 'point', 'view', 'file', 'json', 'parameters', 'way', '#', 'client', 'javascript', 'code', 'file', 'call', 'browser', 'file', 'server', 'headers', 'idea', 'pdf', 'server', 'json', 'url', 'file', 'call', 'success', 'handler', 'following', 'call', 'server', 'server', 'files', 'storage', 'area', 'way', 'ideas', 'docs', 'response', 'datatype', 'way', 'file', 'request', 'file', 'data', 'uri', 'scheme', 'vinayc', 'answer', 'options', 'form', 'post', 'json', 'data', 'form', '

# -----
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# ['structure', 'sql', 'server', 'database', 'application', 'details', 'family', 'objects', 'attributes', 'others', 'example', 'insurance', 'package', 'liability', 'motor', 'property', 'indemnity', 'cover', 'policy', 'record', 'c', '#', 'policy', 'collection', 'sections', 'section', 'types', 'cover', 'databases', 'choices', 'policy', 'table', 'sections', 'table', 'fields', 'variations', 'policy', 'table', 'section', 'kind', 'cover', 'alternatives', 'queries', 'sections', 'joins', 'nullchecks', 'practice', 'scenario']
# ['structure', 'sql', 'server', 'database', 'application', 'details', 'family', 'objects', 'attributes', 'others', 'example', 'insurance', 'package', 'liability', 'motor', 'property', 'indemnity', 'cover', 'policy', 'record', 'c#', 'policy', 'collection', 'sections', 'section', 'types', 'cover', 'databases', 'choices', 'policy', 'table', 'sections', 'table', 'fields', 'variations', 'policy', 'table', 'section', 'kind', 'cover', 'alternatives', 'queries', 'sections', 'joins', 'nullchecks', 'practice', 'scenario']
# -----
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# ['information', 'ones', 'console', 'window', 'solutions', 'solutions', 'console', 'window', 'title', 'bit', 'windows', 'api', 'way', 'others', 'console', 'window', 'c', '#', 'console', 'application']
# ['information', 'ones', 'console', 'window', 'solutions', 'solutions', 'console', 'window', 'title', 'bit', 'windows', 'api', 'way', 'others', 'console', 'window', 'c#', 'console', 'application']
# -----
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# ['function', 'c', '#', 'collection', 'string', 'values', 'delimiter', 'example']
# ['function', 'c#', 'collection', 'string', 'values', 'delimiter', 'example']
# -----
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# ['c', '#', 'class', 'object', 'object', 'xml', 'way', 'class', 'serialization', 'xml', 'representation', 'class', 'definition', 'xml', 'representation', 'object']
# ['c#', 'class', 'object', 'object', 'xml', 'way', 'class', 'serialization', 'xml', 'representation', 'class', 'definition', 'xml', 'representation', 'object']
# -----
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# ['legacy', 'code', 'extension', 'method', 'keyvalue', 'item', 'value', 'key', 'legacy', 'code', 'job', 'method', 'question', 'problem', 'scenario', 'difference', 'hashtable', 'hashtable', 'item', 'item', 'indexer', 'difference', 'c', '#', 'versions', 'objective', 'method', 'exception', 'user', 'keyvalue', 'method', 'entry', 'value', 'entry', 'keyvalue', 'pair', 'method']
# ['legacy', 'code', 'extension', 'method', 'keyvalue', 'item', 'value', 'key', 'legacy', 'code', 'job', 'method', 'question', 'problem', 'scenario', 'difference', 'hashtable', 'hashtable', 'item', 'item', 'indexer', 'difference', 'c#', 'versions', 'objective', 'method', 'exception', 'user', 'keyvalue', 'method', 'entry', 'value', 'entry', 'keyvalue', 'pair', 'method']
# -----
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# ['difference', 'months', 'dates', 'c', '#', 'method', 'c', '#', 'difference', 'months', 'dates', 'years', 'documentation', 'data', 'days', 'number', 'month', 'days', 'operand', 'values', 'dividing', 'value', 'suggestions']
# ['difference', 'months', 'dates', 'c#', 'method', 'c', '#', 'difference', 'months', 'dates', 'years', 'documentation', 'data', 'days', 'number', 'month', 'days', 'operand', 'values', 'dividing', 'value', 'suggestions']
# -----
# ['difference', 'months', 'dates', 'c#', 'method', 'c', '#', 'difference', 'months', 'dates', 'years', 'documentation', 'data', 'days', 'number', 'month', 'days', 'operand', 'values', 'dividing', 'value', 'suggestions']
# ['difference', 'months', 'dates', 'c#', 'method', 'c#', 'difference', 'months', 'dates', 'years', 'documentation', 'data', 'days', 'number', 'month', 'days', 'operand', 'values', 'dividing', 'value', 'suggestions']
# -----
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# 
 'methods', 'marxidad', 'methods', 'jon', 'erickson', 'directives', 'john', 'asbeck', 'preprocessor', 'directive', 'robert', 'durgin', 'operator', 'sefbkn', 'type', 'inferrence', 'chakrit', 'boolean', 'operators', 'level', 'rob', 'gough', 'pass', 'valuetype', 'variable', 'interface', 'boxing', 'roman', 'boiko', 'type', 'boiko', 'constructors', 'chris', 'easierontheeyes', 'linq', 'zac', 'bowling', 'studio', 'block', 'text', 'editor', 'himadri', 'snippets', 'framework', 'kiwibastard', 'kiwibastard', 'iainmh', 'diago', 'juan', 'manuel', 'methods', 'properties', 'method', 'methods', 'properties', 'rismo', 'method', 'john', 'sheehan', 'tips', 'method', 'event', 'handlers', 'andreas', 'hr', 'nilsson', 'uppercase', 'comparisons', 'john', 'access', 'types', 'reflection', 'dp', 'way', 'collection', 'properties', 'anonymous', 'inlinefunctions', 'netmodules', 'kokos', 'linqbridge', 'extensions', 'joel']
# -----
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# ['linq', 'statement', 'syntax', 'join', 'clause', 'c', '#', 'following', 'linq']
# ['linq', 'statement', 'syntax', 'join', 'clause', 'c#', 'following', 'linq']
# -----
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# ['c', '#', 'developer', 'project', 'python', 'equivalent', 'enum', 'python']
# ['c#', 'developer', 'project', 'python', 'equivalent', 'enum', 'python']
# -----
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# ['c', 'support', 'raii', 'idiom', 'difference', 'cs', 'raii', 'idiom', 'c', '#', 's', 'statement']
# ['c', 'support', 'raii', 'idiom', 'difference', 'cs', 'raii', 'idiom', 'c#', 's', 'statement']
# -----
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# ['typedef', 'equivalent', 'c', '#', 'sort', 'behaviour', 'googling', 'situation', 'rocket', 'scientist', 'lot', 'apologies', 'pun', 'handler', 'event', 'd', 'case', 'type', 'int', 'edit', 'eventhandler', 'behaviour']
# ['typedef', 'equivalent', 'c#', 'sort', 'behaviour', 'googling', 'situation', 'rocket', 'scientist', 'lot', 'apologies', 'pun', 'handler', 'event', 'd', 'case', 'type', 'int', 'edit', 'eventhandler', 'behaviour']
# -----
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# ['object', 'documentation', 'says', 'day', 'date', 'date', 'day', 'one', 'number', 'times', 'c', '#']
# ['object', 'documentation', 'says', 'day', 'date', 'date', 'day', 'one', 'number', 'times', 'c#']
# -----
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# ['terms', 'reference', 'code', 'c', 'c', '#']
# ['terms', 'reference', 'code', 'c', 'c#']
# -----
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# ['column', 'object', 'data', 'access', 'layer', 'method', 'object', 'procedures', 'procedures', 'column', 'procedures', 'method', 'scenario', 'application', 'c', '#']
# ['column', 'object', 'data', 'access', 'layer', 'method', 'object', 'procedures', 'procedures', 'column', 'procedures', 'method', 'scenario', 'application', 'c#']
# -----
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# ['benefitdownside', 'statement', 'c', '#', 'difference', 'look', 'code', 'reason', 'il', 'runtime', 'performance', 'switch', 'string', 'elseif', 'type']
# ['benefitdownside', 'statement', 'c#', 'difference', 'look', 'code', 'reason', 'il', 'runtime', 'performance', 'switch', 'string', 'elseif', 'type']
# -----
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# ['byte', 'arrays', 'c', '#', 'method', 'task']
# ['byte', 'arrays', 'c#', 'method', 'task']
# -----
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# ['c', '#', 'advantages', 'way', 'example', 'way', 'semantics', 'matter', 'taste', 'reference', 'c', '#']
# ['c#', 'advantages', 'way', 'example', 'way', 'semantics', 'matter', 'taste', 'reference', 'c', '#']
# -----
# ['c#', 'advantages', 'way', 'example', 'way', 'semantics', 'matter', 'taste', 'reference', 'c', '#']
# ['c#', 'advantages', 'way', 'example', 'way', 'semantics', 'matter', 'taste', 'reference', 'c#']
# -----
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# ['c', '#', 'net', 'data', 'class', 'attribute', 'class', 'constructor', 'exception', 'error', 'type', 'data', 'class', 'object', 'attribute', 'object', 'objects']
# ['c#', 'net', 'data', 'class', 'attribute', 'class', 'constructor', 'exception', 'error', 'type', 'data', 'class', 'object', 'attribute', 'object', 'objects']
# -----
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# ['c', '#', 'languages', 'loop', 'difference', 'means', 'structure', 'loop', 'iteration', 'example']
# ['c#', 'languages', 'loop', 'difference', 'means', 'structure', 'loop', 'iteration', 'example']
# -----
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# ['c', '#', 'threads', 'example', 'threads', 'd', 'way', 'thread', 'i', 'd', 'thread', 'properties', 'studio', 'ids', 'threads', 'way', 'handle', 'thread', 'i', 'd', 'example']
# ['c#', 'threads', 'example', 'threads', 'd', 'way', 'thread', 'i', 'd', 'thread', 'properties', 'studio', 'ids', 'threads', 'way', 'handle', 'thread', 'i', 'd', 'example']
# -----
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# --------------------
# ...
# 16436    None
# 16437    None
# 16438    None
# 16440    None
# 16441    None
# 16442    None
# 16443    None
# 16444    None
# 16445    None
# 16446    None
# 16447    None
# 16449    None
# 16450    None
# 16452    None
# 16453    None
# 16454    None
# 16455    None
# 16456    None
# 16458    None
# 16459    None
# 16461    None
# 16463    None
# 16464    None
# 16465    None
# 16466    None
# 16467    None
# 16468    None
# 16469    None
# 16470    None
# 16471    None
# 16472    None
# 16473    None
# 16474    None
# 16475    None
# 16476    None
# 16477    None
# 16478    None
# 16480    None
# 16481    None
# 16482    None
# 16483    None
# 16485    None
# 16486    None
# 16487    None
# 16488    None
# 16489    None
# 16490    None
# 16491    None
# 16492    None
# 16493    None
# 16494    None
# 16495    None
# 16496    None
# 16497    None
# 16498    None
# 16499    None
# 16500    None
# 16501    None
# 16502    None
# 16503    None
# 16504    None
# 16505    None
# 16506    None
# 16507    None
# 16508    None
# 16509    None
# 16511    None
# 16512    None
# 16513    None
# 16514    None
# 16515    None
# 16516    None
# 16517    None
# 16518    None
# 16519    None
# 16521    None
# 16522    None
# 16523    None
# 16524    None
# 16525    None
# 16526    None
# 16527    None
# 16528    None
# 16529    None
# 16530    None
# 16531    None
# 16532    None
# 16533    None
# 16536    None
# 16537    None
# 16538    None
# 16539    None
# 16540    None
# 16541    None
# 16542    None
# 16543    None
# 16544    None
# 16545    None
# 16547    None
# 16548    None
# 16549    None
# 16550    None
# 16551    None
# 16553    None
# 16554    None
# 16555    None
# 16556    None
# 16557    None
# 16558    None
# 16560    None
# 16561    None
# 16562    None
# 16563    None
# 16564    None
# 16565    None
# 16567    None
# 16569    None
# 16570    None
# 16572    None
# 16573    None
# 16574    None
# 16576    None
# 16577    None
# 16578    None
# 16579    None
# 16580    None
# 16581    None
# 16582    None
# 16583    None
# 16584    None
# 16585    None
# 16586    None
# 16587    None
# 16588    None
# 17632    None
# 17633    None
# 17634    None
# 17636    None
# 17637    None
# 17638    None
# 17639    None
# 17640    None
# 17641    None
# 17643    None
# 17644    None
# 17646    None
# 17647    None
# 17648    None
# 17649    None
# 17650    None
# 17651    None
# 17652    None
# 17654    None
# 17655    None
# 17656    None
# 17657    None
# 17658    None
# 17659    None
# 17660    None
# 17661    None
# 17662    None
# 17663    None
# 17664    None
# 17665    None
# 17666    None
# 17667    None
# 17669    None
# 17670    None
# 17673    None
# 17674    None
# 17675    None
# 17676    None
# 17677    None
# 17679    None
# 17680    None
# 17681    None
# 17682    None
# 17683    None
# 17686    None
# 17688    None
# 17689    None
# 17690    None
# 17691    None
# 17692    None
# 17693    None
# 17696    None
# 17697    None
# 17698    None
# 17699    None
# 17700    None
# 17701    None
# 17702    None
# 17704    None
# 17705    None
# 17706    None
# 17707    None
# 17709    None
# 17710    None
# 17712    None
# 17714    None
# 17715    None
# 17717    None
# 17718    None
# 17719    None
# 17720    None
# 17722    None
# 17723    None
# 17724    None
# 17726    None
# 17727    None
# 17728    None
# 17729    None
# 17730    None
# 17731    None
# 17732    None
# 17733    None
# 17734    None
# 17735    None
# 17737    None
# 17738    None
# 17739    None
# 17741    None
# 17743    None
# 17744    None
# 17745    None
# 17746    None
# 17747    None
# 17750    None
# 17751    None
# 17752    None
# 17753    None
# 17754    None
# 17755    None
# 17756    None
# 17758    None
# 17760    None
# 17763    None
# 17764    None
# 17765    None
# 17767    None
# 17768    None
# 17769    None
# 17771    None
# 17772    None
# 17775    None
# 17776    None
# 17777    None
# 17778    None
# 17780    None
# 17781    None
# 17782    None
# 17783    None
# 17785    None
# 17786    None
# 17787    None
# 17788    None
# 17789    None
# 17790    None
# 17791    None
# 17793    None
# 17794    None
# 17795    None
# 17796    None
# 17797    None
# 17799    None
# 17800    None
# 17801    None
# 17802    None
# 17804    None
# 17805    None
# 17806    None
# 17807    None
# Name: MainWordBody, dtype: object

# %%
# Lemmatizer
wn = nltk.WordNetLemmatizer()
dataStack['MainWordBody'] = dataStack['MainWordBody'].apply(lambda x : [wn.lemmatize(word) for word in x])
print(dataStack['MainWordBody'].head())

# %%
# StopWords
sw = set()
sw.update(tuple(nltk.corpus.stopwords.words('english')))

dataStack['MainWordBody'] = dataStack['MainWordBody'].apply(lambda x : [mot for mot in x
                       if mot not in sw])

# %%
listBody = getWord('MainWordBody')

# %%
# Word cloud 
fig = plt.figure(1, figsize=(10, 8))
ax = fig.add_subplot(1, 1, 1)
wordcloud = WordCloud(width=900, height=500,
                      background_color="black",
                      max_words=500, relative_scaling=1,
                      normalize_plurals=False)\
    .generate_from_frequencies(listBody.to_dict()['Count'])

ax.imshow(wordcloud, interpolation='bilinear')
ax.axis("off")
plt.title("Word Cloud des 40 meilleurs tags sur StackOverflow\n",
          fontsize=18, color="#641E16")
plt.show()

# %% [markdown]
# # Data saved

# %%
dataStack[['Id','MainTags','MainWordBody','MainWordTitle','CreationYear']].to_csv("../QueryResults_Clear.csv",index=False)
